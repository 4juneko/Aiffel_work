# %% [markdown]
# #### 1. 아래 내용을 참고하여 Player 클래스를 만드세요.
# 1. Player 클래스 생성
# 2. player는 닉네임, HP, MP를 가짐(속성)
# 3. player는 다른 player을 상대로 공격, 스킬, 방어를 가능(함수로 구현)
# 4. (선택사항)속성이나 player 행동에 대한 함수를 자유롭게 추가해도 됨

# %%
# your code
# 정해진 답은 없음, 클래스를 이해하고자라는 의도로 만든 문제

class Player:
    def __init__(self, nickname, HP, MP):
      self.nickname=nickname
      self.HP=HP
      self.MP=MP

    def attack(self):
      print(self.nickname,'공격',self.HP)

    def skill(self):
      print(self.nickname,'스킬',self.MP)
       

    def heal(self):
      self.HP=0
      self.MP=0

def game():

  player1=Player('june',20,15)
  player2=Player('jk',30,10)
  player1.skill()
  player2.attack()

game()

# %% [markdown]
# #### 2. 아래와 같이 출력 결과가 나오도록 Account 클래스를 만드세요.(your code 부분 작성)
# ```
# 은행이름: SC은행
# 계좌번호: 670-14-689475
# --------------------
# 총 계좌수: 2
# 총 계좌수: 3
# --------------------
# 5
# --------------------
# 100
# 200
# --------------------
# 은행이름: SC은행
# 예금주: 파이썬
# 계좌번호: 973-96-615694
# 잔고: 10,000
# --------------------
# 110
# --------------------
# 100
# 200
# 300
# --------------------
# 100
# 200
# --------------------
# ```

# %%
import random

class Account:
    # 클래스 변수
    account_count = 0
#deposit_count, deposit_log, withdraw_log, bank,account_number,
    def __init__(self, name,  balance):
        self.deposit_count = 0  # 입금횟수 초기화
        self.deposit_log = []   # 입금내역
        self.withdraw_log = []  # 출금내역

        # 빠뜨린 속성 추가 구현
        self.bank = "SC은행"
        self.name=name
        self.balance=balance

        # 랜덤하게 개좌번호 생성을 구현
        num1=str(random.choice(range(100,999)))
        num2=str(random.choice(range(10,99)))
        num3=str(random.choice(range(100000,999999)))
        self.account_number = num1 + '-' + num2 + '-' + num3
        Account.account_count += 1
  
    @classmethod
    def get_account_num(cls):
        print(cls.account_count)


    def deposit(self, amount):
        if amount > 1:
            self.deposit_log.append(amount)
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:   # 5, 10, 15 ...
                self.balance *= 1.01            # 이자


    def withdraw(self, amount):
        if self.balance > amount:
            self.withdraw_log.append(amount)
            self.balance -= amount


    def display_info(self):
        # 정보출력을 구현
        print('은행이름 : ', self.bank)
        print('예금주 :', self.name)
        print('계좌번호 : ', self.account_number)
        print('잔고 :', self.balance)
        # print('-'*20)
  
    def deposit_history(self):
        # 예금 히스토리 출력을 구현
        for i in self.deposit_log:
          print(i)


    def withdraw_history(self):
        # 출금 히스토리 출력을 구현
        for i in self.withdraw_log:
          print(i)


kim = Account("김민수", 100)
print("은행이름:", kim.bank) 
print("계좌번호:", kim.account_number) 
print('-'*20)

kim = Account("김민수", 100)
print("총 계좌수:", Account.account_count)
lee = Account("이민수", 100)
print("총 계좌수:", Account.account_count)
print('-'*20)

kim = Account("김민수", 100)
lee = Account("이민수", 100)
Account.get_account_num()
print('-'*20)

kim = Account("김민수", 100)
kim.deposit(1)
print(kim.balance)
kim.deposit(100)
print(kim.balance)
print('-'*20)

p = Account("파이썬", 10000)
p.display_info()
print('-'*20)

kim = Account("김민수", 100)
kim.deposit(100)
kim.withdraw(90)
print(kim.balance)
print('-'*20)

p = Account("파이썬", 10000)
p.deposit(100)
p.deposit(200)
p.deposit(300)
p.deposit_history()
print('-'*20)

p.withdraw(100)
p.withdraw(200)
p.withdraw_history()
print('-'*20)
# Out:
# 은행이름: SC은행
# 계좌번호: 418-53-451504
# --------------------
# 총 계좌수: 2
# 총 계좌수: 3
# --------------------
# 5
# --------------------
# 100
# 200
# --------------------
# 은행이름 :  SC은행
# 예금주 : 파이썬
# 계좌번호 :  114-27-702201
# 잔고 : 10000
# --------------------
# 110
# --------------------
# 100
# 200
# 300
# --------------------
# 100
# 200
# --------------------

# %% [markdown]
# #### 3.상점 관리 시스템 만들기(파일 입출력 문제)
#
# 상점 데이터를 추가하고 원하는 column을 선택하여 읽을 수 있는 프로그램 만드시오.
#
# 각 상점 데이터 : (상점 이름, 위치, 판매 상품, 전화번호)

# %% [markdown]
# ### (3/9 이후) 람다 연습문제

# %%
# # 상점 데이터 예시
baeks_stores = [
    {
        'name' : '빽다방 인천송도점',
        'location' : '인천광역시 연수구 컨벤시아대로 81 드림시티빌딩',
        'goods' : '커피',
        'num' : '032-453-3245'
    },
    {
        'name' : '새마을 식당 인천구월점',
        'location' : '인천광역시 남동구 인하로507번길 9 103',
        'goods' : '고기',
        'num' : '032-341-7562'
    },
    {
        'name' : '빽다방 구월로데오점',
        'location' : '인천 남동구 성말로 9 이노프라자',
        'goods' : '커피',
        'num' : '042-245-5324'
    },
    {
        'name' : '홍콩반점 인천송도점',
        'location' : '인천광역시 연수구 컨벤시아대로 81 드림시티',
        'goods' : '중식',
        'num' : '123-457-8999'
    }
]
 
# 필요한 기능 및 출력 예시
# 1. 상점의 데이터를 csv 파일에 등록하는 기능 => 출력 : “성공적으로 등록되었습니다 “ / 결과 : csv 파일에 등록한 이름 잘 들어갈것
# 2. 상점들의 이름을 모두 출력하는 기능 => 출력 : “빽다방 인천송도점, 새마을 식당 인천구월점, 빽다방 구월로데오점, 홍콩반점 인천송도점"
# 3. 상점의 이름을 입력 받으면, 해당 상점의 위치를 출력하는 기능 => 출력 : “빽다방 인천송도점의 위치는 대전광역시 유성구 죽동로 295 입니다. / 없을 경우 : "입력하신 이름의 상점이 없습니다."
# 4. 상점의 이름을 입력 받으면, 해당 상점의 판매하는 상품을 출력하는 기능 => 출력 : “빽다방 인천송도점은 커피를 판매합니다.” / 없을 경우 : "입력하신 이름의 상점이 없습니다."
# 5. 상점의 이름을 입력 받으면, 해당 상점의 전화번호를 출력하는 기능 => 출력 : “빽다방 인천송도점의 전화번호는 032-453-3245 입니다.” / 없을 경우 : "입력하신 이름의 상점이 없습니다."

import csv
import os

keys = list(baeks_stores[0].keys())
print(keys)

with open('store_list.csv','w', newline='', encoding = 'ANSI') as f: #utf-8로 하면 엑셀에서 한글이 깨짐
    write=csv.writer(f)
    write.writerow(keys)
    
    for i in range(len(baeks_stores)):
        for j in baeks_stores[i].values():
            data=''.join(j)
            f.write(data+',')
        f.write(data+'\n')
    f.close()    


def main() :

    while True:
        selected = str(input('1 - 상점추가, 2 - 상점 모두 보기, 3 - 상점 위치 찾기, 4 - 판매하는 상품 종 류 보기, 5 - 상점 전화번호 찾기, 0 - 프로그램 종료'))

    # TODO 0. csv 파일이 생성되지 않으면 읽을 수 없습니다. TODO 1의 등록하는 기능을 구현하여, 예시 데이터를 Write 하는 과정을 먼저 수행해주세요.
    
        if selected == '1' :
    # TODO 1. 상점의 데이터를 csv 파일에 등록하는 기능
    # - 상점의 이름, 위치, 상품종류, 전화번호를 예시 데이터에 맞게 입력을 받기
    # - 입력 받은 데이터를 csv 파일에 write
            with open('store_list.csv','a',newline='') as f:
                write=csv.writer(f)
                name=str(input('가게이름'))
                location=str(input('주소'))
                goods=str(input('상품'))
                num=str(input('전화번호, ***-***-**** 형태로'))
                f.close()


        elif selected == '2' :
        # TODO 2. 상점의 이름을 모두 출력하는 기능
        # - csv 에 등록되어 있는 모든 파일의 이름을 출력하기

            f=open('store_list.csv','r')
            reader=csv.reader(f)
            for info in reader:
                print(info[0])
            file_list=os.listdir('D:/python/jupyter_note_python/aiffel')
            file_list_py = [file for file in file_list if file.endswith('.csv')]
            print(file_list_py)
            f.close

        elif selected == '3' :
        # TODO 3. 상점 위치 찾기 기능
        # - 상점 이름을 입력받고, 해당 상점의 위치를 출력 해주기
            name=str(input('위치 알고 싶은 가게 이름?'))
            f=open('store_list.csv','r')
            reader=csv.reader(f)
            for info in reader:
                if name == info[0]:
                    print(info[1])
            f.close()


        elif selected == '4' :
        # TODO 4. 판매하는 물건 보기
        # - 상점 이름을 입력받고, 해당 상점의 판매하는 상품 종류 출력 해주기
            name=str(input('상품 알고 싶은 가게 이름?'))
            f=open('store_list.csv','r')
            reader=csv.reader(f)
            for info in reader:
                if name == info[0]:
                    print(info[2])
            f.close()

        elif selected == '5' :
        # TODO 5. 상점 전화번호 찾기
        # - 상점 이름을 입력받고, 해당 상점의 전화번호를 출력하는 기능
            name=str(input('전화번호 알고 싶은 가게 이름?'))
            f=open('store_list.csv','r')
            reader=csv.reader(f)
            for info in reader:
                if name == info[0]:
                    print(info[3])
            f.close()

        elif selected == '0':
            break
#             exit()
        
  
  # 메인 함수 실행 => 반복 필요

main()
# Out:
# ['name', 'location', 'goods', 'num']

# %% [markdown]
# #### 1.1~10 사이의 숫자가 들어있는 test_list 객체에서 filter 함수와 람다식을 이용해 짝수만을 선택해 리스트를 반환하는 프로그램을 작성하십시오.

# %%
test_list = [1, 2, 4, 7, 9, 10]

even_no = list(filter(lambda x : x%2 == 0, test_list))
print(even_no)

# your code


# 출력 예시 #
# [2, 4, 10]

# %% [markdown]
# #### 2."ADCBBBBCABBCBDACBDCAACDDDCAABABDBCBCBDBDBDDABBAAAAAAADADBDBCBDABADCADC"와 같은 문자열이 주어지고, A는 4점, B는 3점, C는 2점, D는 1점이라고 할 때 문자열에 사용된 알파벳 점수의 총합을 map 함수와 람다식을 이용해 구하십시오.
#
# - 1.change 라는 함수구현
# - 2.change 함수를 호출하고, map함수와 람다식을 사용하여 입력 텍스트의 값을 계산

# %%
input_text = "ADCBBBBCABBCBDACBDCAACDDDCAABABDBCBCBDBDBDDABBAAAAAAADADBDBCBDABADCADC"

def change(string):
    # your code 1
    point = list(map(lambda x : 4 if x=='A' else( 3 if x == 'B' else( 2 if x == 'C' else 1)),list(string)))
    return point

sum(change(input_text))
# Out:
# 184

# %%
class Player:
  def __init__(self,nickname,hp,mp,damage,defence):
    self.nickname = nickname
    self.HP = hp
    self.MP = mp
    self.damage = damage
    self.defence = defence
    print(f'"{self.nickname}"님이 생성 되었습니다.')
    print(f'체력 : {self.HP}, 마나: {self.MP},공격력:{self.damage}, 방어력:{self.defence} ')

  def attack(self,target):
    if self.damage > target.defence:
      target.HP = target.HP -(self.damage - target.defence)
      self.MP -= 10
      A = self.MP
      print(A,"공격 스킬을 사용하여 MP를 10차감하였습니다.\n",target.nickname,"을 공격하였습니다.(",target.HP,")" )
